# %%
import pandas as pd

# %%
df1 = pd.read_csv("ak_dgtl_archv_artst_list_2019.csv")

# %%
df1.columns = ['art_grp_se', 'archv_artst_nm', 'nm', 'vrit_mark_cn', 'realm_cl', 'act_relm_cn', 'birth_year', 'rsrch_man_nm', 'url']

# %%
df1 = df1.drop(['url'], axis=1)

# %%
df1
# Out:
#      art_grp_se archv_artst_nm       nm    vrit_mark_cn realm_cl act_relm_cn  \
# 0        FARTST           미술작가  김영구(김영)             NaN       회화         NaN
# 1        FARTST           미술작가      박동우   Park Dong Woo     무대미술         NaN
# 2        FARTST           미술작가      유지원             柳智元       회화         NaN
# 3         ARTST            예술인      강경구  Kang kyung koo     시각예술        미술작가
# 4         ARTST            예술인      강관욱  Kang kwan wook     시각예술        미술작가
# ...         ...            ...      ...             ...      ...         ...
# 1862        DIC           구술채록      황금찬             黃錦燦       문학          문학
# 1863        DIC           구술채록      황수영             黃壽永     시각예술        미술이론
# 1864        DIC           구술채록      황정순             黃貞順     대중예술        대중예술
# 1865        DIC           구술채록      황종례             黃鍾禮     시각예술          공예
# 1866        DIC           구술채록      황창호             黃昌鎬     공연예술          무용
#
#       birth_year rsrch_man_nm
# ...

# %%
df2 = pd.read_csv("ak_dgtl_archv_artst_list_2020.csv")

# %%
df2.columns = ['art_grp_se', 'archv_artst_nm', 'nm', 'vrit_mark_cn', 'realm_cl', 'act_relm_cn', 'birth_year', 'rsrch_man_nm', 'url']

# %%
df2 = df2.drop(['url'], axis=1)

# %%
df2
# Out:
#      art_grp_se archv_artst_nm       nm    vrit_mark_cn realm_cl act_relm_cn  \
# 0        FARTST           미술작가  김영구(김영)             NaN       회화         NaN
# 1        FARTST           미술작가      박동우   Park Dong Woo     무대미술         NaN
# 2        FARTST           미술작가      유지원             柳智元       회화         NaN
# 3         ARTST            예술인      강경구  Kang kyung koo     시각예술        미술작가
# 4         ARTST            예술인      강관욱  Kang kwan wook     시각예술        미술작가
# ...         ...            ...      ...             ...      ...         ...
# 1862        DIC           구술채록      황금찬             黃錦燦       문학          문학
# 1863        DIC           구술채록      황수영             黃壽永     시각예술        미술이론
# 1864        DIC           구술채록      황정순             黃貞順     대중예술        대중예술
# 1865        DIC           구술채록      황종례             黃鍾禮     시각예술          공예
# 1866        DIC           구술채록      황창호             黃昌鎬     공연예술          무용
#
#       birth_year rsrch_man_nm
# ...

# %%
df3 = pd.read_csv("ak_dgtl_archv_artst_list_2021.csv")

# %%
df3.columns = ['art_grp_se', 'archv_artst_nm', 'nm', 'vrit_mark_cn', 'realm_cl', 'act_relm_cn', 'birth_year', 'rsrch_man_nm', 'url']

# %%
df3 = df3.drop(['url'], axis=1)

# %%
df3
# Out:
#      art_grp_se archv_artst_nm           nm    vrit_mark_cn realm_cl  \
# 0         ARTST            예술인          심옥식     SHIM Okshik     창작음악
# 1         ARTST            예술인          장민석   JANG Min Seok     창작음악
# 2         ARTST            예술인          홍현숙  Hong hyun sook     시각예술
# 3         ARTST            예술인          계낙영   Kye nak young     시각예술
# 4         ARTGR           예술단체  극단 산으로 간 어부             NaN     공연단체
# ...         ...            ...          ...             ...      ...
# 2017      ARTST            예술인          구히서             具熙書     공연예술
# 2018     FARTST           미술작가          조남붕   Cho nam boong       사진
# 2019      ARTST            예술인          오수환       Oh su fan     시각예술
# 2020      ARTST            예술인          임영미   LYMN Youngmee     창작음악
# 2021      ARTST            예술인           전준       Chon joon     시각예술
#
#      act_relm_cn  birth_year rsrch_man_nm
# 0         한국현대음악      1959.0          NaN
# 1         한국현대음악      1995.0          NaN
# ...

# %%
df4 = pd.read_csv("ak_dgtl_archv_artst_list_2022.csv")

# %%
df4.columns = ['art_grp_se', 'archv_artst_nm', 'nm', 'vrit_mark_cn', 'realm_cl', 'act_relm_cn', 'birth_year', 'rsrch_man_nm', 'url']

# %%
df4 = df4.drop(['url'], axis=1)

# %%
df4
# Out:
#      art_grp_se archv_artst_nm                  nm    vrit_mark_cn realm_cl  \
# 0         ARTST            예술인                 심옥식     SHIM Okshik     창작음악
# 1         ARTST            예술인                 홍현숙  Hong hyun sook     시각예술
# 2         ARTST            예술인                 계낙영   Kye nak young     시각예술
# 3        FARTST           미술작가                 김보희      Kim bo hie       회화
# 4         ARTST            예술인                 박광순             NaN     시각예술
# ...         ...            ...                 ...             ...      ...
# 2232      ARTST            예술인                 김태호      Kim tae ho     시각예술
# 2233      ARTST            예술인                 조진옥       CHO Jinok     창작음악
# 2234      ARTGR           예술단체  한국문화예술위원회 아르코예술기록원             NaN       기타
# 2235      ARTGR           예술단체            울주문화예술회관             NaN      공연장
# 2236      ARTST            예술인                 박성원   BAHK Soungwon     창작음악
#
#      act_relm_cn  birth_year rsrch_man_nm
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   art_grp_se      1867 non-null   object
#  1   archv_artst_nm  1867 non-null   object
#  2   nm              1867 non-null   object
#  3   vrit_mark_cn    1750 non-null   object
#  4   realm_cl        1860 non-null   object
#  5   act_relm_cn     1344 non-null   object
#  6   birth_year      1813 non-null   float64
#  7   rsrch_man_nm    252 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 116.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   art_grp_se      1867 non-null   object
#  1   archv_artst_nm  1867 non-null   object
#  2   nm              1867 non-null   object
#  3   vrit_mark_cn    1750 non-null   object
#  4   realm_cl        1860 non-null   object
#  5   act_relm_cn     1344 non-null   object
#  6   birth_year      1813 non-null   float64
#  7   rsrch_man_nm    252 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 116.8+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2022 entries, 0 to 2021
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   art_grp_se      2022 non-null   object
#  1   archv_artst_nm  2022 non-null   object
#  2   nm              2022 non-null   object
#  3   vrit_mark_cn    1805 non-null   object
#  4   realm_cl        2006 non-null   object
#  5   act_relm_cn     1407 non-null   object
#  6   birth_year      1714 non-null   float64
#  7   rsrch_man_nm    262 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 126.5+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   art_grp_se      2237 non-null   object
#  1   archv_artst_nm  2237 non-null   object
#  2   nm              2237 non-null   object
#  3   vrit_mark_cn    1936 non-null   object
#  4   realm_cl        2221 non-null   object
#  5   act_relm_cn     1616 non-null   object
#  6   birth_year      1925 non-null   float64
#  7   rsrch_man_nm    281 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 139.9+ KB

# %%
df = pd.concat([df1, df2, df3, df4], axis=0)

# %%
df
# Out:
#      art_grp_se archv_artst_nm                  nm    vrit_mark_cn realm_cl  \
# 0        FARTST           미술작가             김영구(김영)             NaN       회화
# 1        FARTST           미술작가                 박동우   Park Dong Woo     무대미술
# 2        FARTST           미술작가                 유지원             柳智元       회화
# 3         ARTST            예술인                 강경구  Kang kyung koo     시각예술
# 4         ARTST            예술인                 강관욱  Kang kwan wook     시각예술
# ...         ...            ...                 ...             ...      ...
# 2232      ARTST            예술인                 김태호      Kim tae ho     시각예술
# 2233      ARTST            예술인                 조진옥       CHO Jinok     창작음악
# 2234      ARTGR           예술단체  한국문화예술위원회 아르코예술기록원             NaN       기타
# 2235      ARTGR           예술단체            울주문화예술회관             NaN      공연장
# 2236      ARTST            예술인                 박성원   BAHK Soungwon     창작음악
#
#      act_relm_cn  birth_year rsrch_man_nm
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7993 entries, 0 to 2236
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   art_grp_se      7993 non-null   object
#  1   archv_artst_nm  7993 non-null   object
#  2   nm              7993 non-null   object
#  3   vrit_mark_cn    7241 non-null   object
#  4   realm_cl        7947 non-null   object
#  5   act_relm_cn     5711 non-null   object
#  6   birth_year      7265 non-null   float64
#  7   rsrch_man_nm    1047 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 562.0+ KB

# %%
df.tail()
# Out:
#      art_grp_se archv_artst_nm                  nm   vrit_mark_cn realm_cl  \
# 2232      ARTST            예술인                 김태호     Kim tae ho     시각예술
# 2233      ARTST            예술인                 조진옥      CHO Jinok     창작음악
# 2234      ARTGR           예술단체  한국문화예술위원회 아르코예술기록원            NaN       기타
# 2235      ARTGR           예술단체            울주문화예술회관            NaN      공연장
# 2236      ARTST            예술인                 박성원  BAHK Soungwon     창작음악
#
#      act_relm_cn  birth_year rsrch_man_nm
# 2232        미술작가      1948.0          NaN
# 2233      한국현대음악      1979.0          NaN
# 2234         NaN         NaN          NaN
# 2235         NaN         NaN          NaN
# 2236      한국현대음악      1976.0          NaN

# %%
df.to_excel("dongik.xlsx", encoding="utf-8")

# %%
df.isnull().sum()
# Out:
# art_grp_se           0
# archv_artst_nm       0
# nm                   0
# vrit_mark_cn       752
# realm_cl            46
# act_relm_cn       2282
# birth_year         728
# rsrch_man_nm      6946
# dtype: int64
